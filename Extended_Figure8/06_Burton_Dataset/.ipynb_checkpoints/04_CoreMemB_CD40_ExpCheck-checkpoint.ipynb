# %%
import scanpy as sc
import pandas as pd 
import numpy as np
import sys
import matplotlib.pyplot as plt
import gc
import anndata
from adjustText import adjust_text
import seaborn as sns
from scipy.stats import mannwhitneyu
def grouped_obs_sum_raw(adata_filt, group_key, layer=None, gene_symbols=None):
    if layer is not None:
        getX = lambda x: x.layers[layer]
    else:
        getX = lambda x: x.X
    if gene_symbols is not None:
        idx = adata_filt.var_names.isin(gene_symbols)
        new_idx = adata_filt.var_names[idx]
    else:
        new_idx = adata_filt.var_names
    grouped = adata_filt.obs.groupby(group_key)
    out = pd.DataFrame(
        np.zeros((len(new_idx), len(grouped)), dtype=np.float64),
        columns=list(grouped.groups.keys()),
        index=new_idx
    )
    for group, idx in grouped.indices.items():
        X = getX(adata_filt[idx])
        out[group] = np.ravel(X.sum(axis=0, dtype=np.float64))
    return out

def grouped_obs_mean(adata_filt, group_key, layer=None, gene_symbols=None):
    if layer is not None:
        getX = lambda x: x.layers[layer]
    else:
        getX = lambda x: x.X
    if gene_symbols is not None:
        idx = adata_filt.var_names.isin(gene_symbols)
        new_idx = adata_filt.var_names[idx]
    else:
        new_idx = adata_filt.var_names
    grouped = adata_filt.obs.groupby(group_key)
    out = pd.DataFrame(
        np.zeros((len(new_idx), len(grouped)), dtype=np.float64),
        columns=list(grouped.groups.keys()),
        index=new_idx
    )
    for group, idx in grouped.indices.items():
        X = getX(adata_filt[idx])
        out[group] = np.ravel(X.mean(axis=0, dtype=np.float64))
    return out

# %%
adata=sc.read_h5ad("adata_processed.h5ad")

# %%
adata.obs["AIFI_L3"].unique()
# Out:
# ['Core naive B cell', 'Core memory B cell', 'Activated memory B cell', 'Core naive CD4 T cell', 'CD27- effector B cell', ..., 'pDC', 'Core CD14 monocyte', 'ISG+ naive B cell', 'Core naive CD8 T cell', 'Erythrocyte']
# Length: 17
# Categories (17, object): ['Activated memory B cell', 'CD14+ cDC2', 'CD27+ effector B cell', 'CD27- effector B cell', ..., 'Plasma cell', 'Platelet', 'Transitional B cell', 'pDC']

# %%
gene_name = 'CD40'

adata_subset = adata[adata.obs["AIFI_L3"] == "Core memory B cell"]

raw_count_sum = grouped_obs_sum_raw(adata_subset, "donor")
sc.pp.normalize_total(adata_subset, target_sum=1e4)
sc.pp.log1p(adata_subset)
normalized_count_average = grouped_obs_mean(adata_subset, "donor")

df_exp = pd.DataFrame(normalized_count_average.loc[gene_name, :])
metadata = adata_subset.obs[["donor", "days", "age_group"]].drop_duplicates()
metadata.index = metadata['donor'].tolist()

merged_df = pd.merge(metadata, df_exp, left_index=True, right_index=True)

stat, p_value = mannwhitneyu(
    merged_df[merged_df['age_group'] == 'old'][gene_name],
    merged_df[merged_df['age_group'] == 'young'][gene_name]
)

sns.boxplot(x='age_group', y=gene_name, data=merged_df, palette='Set2')
plt.text(0.5, merged_df[gene_name].max() + 0.1, f'p = {p_value}', ha='center')
plt.title(f'Boxplot of {gene_name} Expression (Donor Level)')
plt.show()

gene_expression = pd.DataFrame(adata_subset[:, gene_name].X, columns=[gene_name])
gene_expression["donor"] = adata_subset.obs["donor"].tolist()
gene_expression.index = gene_expression['donor'].tolist()

gene_expression_df = pd.merge(metadata, gene_expression, left_index=True, right_index=True)

stat, p_value = mannwhitneyu(
    gene_expression_df[gene_expression_df['age_group'] == 'old'][gene_name],
    gene_expression_df[gene_expression_df['age_group'] == 'young'][gene_name]
)

sns.boxplot(x='age_group', y=gene_name, data=gene_expression_df, palette='Set2')
plt.text(0.5, gene_expression_df[gene_name].max() + 0.5, f'p = {p_value}', ha='center')
plt.title(f'Boxplot of {gene_name} Expression (Single-Cell Level)')
plt.show()
# Out:
# /tmp/ipykernel_1188/1248867749.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = adata_filt.obs.groupby(group_key)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:207: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# WARNING: adata.X seems to be already log-transformed.
# /tmp/ipykernel_1188/1248867749.py:42: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = adata_filt.obs.groupby(group_key)
# /tmp/ipykernel_1188/1569738020.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='age_group', y=gene_name, data=merged_df, palette='Set2')
# /tmp/ipykernel_1188/1569738020.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='age_group', y=gene_name, data=gene_expression_df, palette='Set2')

# %% [markdown]
# #  CD27- effector B

# %%
gene_name = 'IGHM'

adata_subset = adata[adata.obs["AIFI_L3"] == "CD27- effector B cell"]
adata_subset=adata_subset[adata_subset.obs["days"]=="d42"]

raw_count_sum = grouped_obs_sum_raw(adata_subset, "donor")
sc.pp.normalize_total(adata_subset, target_sum=1e4)
sc.pp.log1p(adata_subset)
normalized_count_average = grouped_obs_mean(adata_subset, "donor")

df_exp = pd.DataFrame(normalized_count_average.loc[gene_name, :])
metadata = adata_subset.obs[["donor", "days", "age_group"]].drop_duplicates()
metadata.index = metadata['donor'].tolist()

merged_df = pd.merge(metadata, df_exp, left_index=True, right_index=True)

stat, p_value = mannwhitneyu(
    merged_df[merged_df['age_group'] == 'old'][gene_name],
    merged_df[merged_df['age_group'] == 'young'][gene_name]
)

sns.boxplot(x='age_group', y=gene_name, data=merged_df, palette='Set2')
plt.text(0.5, merged_df[gene_name].max() + 0.1, f'p = {p_value}', ha='center')
plt.title(f'Boxplot of {gene_name} Expression (Donor Level)')
plt.show()

gene_expression = pd.DataFrame(adata_subset[:, gene_name].X, columns=[gene_name])
gene_expression["donor"] = adata_subset.obs["donor"].tolist()
gene_expression.index = gene_expression['donor'].tolist()

gene_expression_df = pd.merge(metadata, gene_expression, left_index=True, right_index=True)

stat, p_value = mannwhitneyu(
    gene_expression_df[gene_expression_df['age_group'] == 'old'][gene_name],
    gene_expression_df[gene_expression_df['age_group'] == 'young'][gene_name]
)

sns.boxplot(x='age_group', y=gene_name, data=gene_expression_df, palette='Set2')
plt.text(0.5, gene_expression_df[gene_name].max() + 0.5, f'p = {p_value}', ha='center')
plt.title(f'Boxplot of {gene_name} Expression (Single-Cell Level)')
plt.show()
# Out:
# WARNING: adata.X seems to be already log-transformed.
# /tmp/ipykernel_1188/1248867749.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = adata_filt.obs.groupby(group_key)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:207: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /tmp/ipykernel_1188/1248867749.py:42: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = adata_filt.obs.groupby(group_key)
# /tmp/ipykernel_1188/2561557669.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='age_group', y=gene_name, data=merged_df, palette='Set2')
# /tmp/ipykernel_1188/2561557669.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='age_group', y=gene_name, data=gene_expression_df, palette='Set2')
