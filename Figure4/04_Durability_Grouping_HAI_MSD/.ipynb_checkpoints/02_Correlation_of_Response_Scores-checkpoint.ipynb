# %%
options(warn=-1)
library(ggplot2)
library(stats)
library(dplyr)
library(tidyverse)
library(rstatix)
library(ggpubr)
library(GGally)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ✔ readr     2.1.5
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
df<-read.csv('lm_res.csv')

# %%
df %>% filter(subjectGuid=="BR1004")
# Out:
#   X                               subjectGuid residual responder
# 1 A/Guangdong-2020-2021.4         BR1004      1.134191 high responder
# 2 Flu B/Phuket HA-2020-2021.4     BR1004      1.847829 high responder
# 3 Flu B/Washington HA-2020-2021.4 BR1004      1.214289 high responder
#   cohort.cohortGuid Assay               Flu_Year
# 1 BR1               A/Guangdong         2020-2021
# 2 BR1               Flu B/Phuket HA     2020-2021
# 3 BR1               Flu B/Washington HA 2020-2021

# %%
head(df)
# Out:
#   X                       subjectGuid residual   responder
# 1 A/Guangdong-2020-2021.1 BR2038      -0.8914245 low responder
# 2 A/Guangdong-2020-2021.2 BR1012      -2.1280354 low responder
# 3 A/Guangdong-2020-2021.3 BR2025      -0.2175159 middle responder
# 4 A/Guangdong-2020-2021.4 BR1004       1.1341906 high responder
# 5 A/Guangdong-2020-2021.5 BR1037      -0.9590861 low responder
# 6 A/Guangdong-2020-2021.6 BR2009      -0.7804310 low responder
#   cohort.cohortGuid Assay       Flu_Year
# 1 BR2               A/Guangdong 2020-2021
# 2 BR1               A/Guangdong 2020-2021
# 3 BR2               A/Guangdong 2020-2021
# 4 BR1               A/Guangdong 2020-2021
# 5 BR1               A/Guangdong 2020-2021
# 6 BR2               A/Guangdong 2020-2021

# %%
df$time_assay<-paste0(df$Flu_Year,'-',df$Assay)

# %%
df[c("subjectGuid","residual","time_assay")]
# Out:
#     subjectGuid residual    time_assay
# 1   BR2038      -0.89142449 2020-2021-A/Guangdong
# 2   BR1012      -2.12803537 2020-2021-A/Guangdong
# 3   BR2025      -0.21751595 2020-2021-A/Guangdong
# 4   BR1004       1.13419058 2020-2021-A/Guangdong
# 5   BR1037      -0.95908607 2020-2021-A/Guangdong
# 6   BR2009      -0.78043096 2020-2021-A/Guangdong
# 7   BR1024      -0.15270083 2020-2021-A/Guangdong
# 8   BR1021      -0.03793972 2020-2021-A/Guangdong
# 9   BR1011      -0.31287221 2020-2021-A/Guangdong
# 10  BR2008       0.48623274 2020-2021-A/Guangdong
# 11  BR1032       0.93757300 2020-2021-A/Guangdong
# 12  BR1026       0.32930872 2020-2021-A/Guangdong
# 13  BR2003       0.59902051 2020-2021-A/Guangdong
# 14  BR2037       1.25652434 2020-2021-A/Guangdong
# 15  BR2005      -0.32503915 2020-2021-A/Guangdong
# 16  BR1028      -0.41963552 2020-2021-A/Guangdong
# 17  BR2015       0.09558575 2020-2021-A/Guangdong
# 18  BR1031       0.06889023 2020-2021-A/Guangdong
# 19  BR1025       1.70650350 2020-2021-A/Guangdong
# 20  BR2010       0.57721667 2020-2021-A/Guangdong
# 21  BR1023       1.01970006 2020-2021-A/Guangdong
# 22  BR1008       0.86282870 2020-2021-A/Guangdong
# 23  BR2033      -1.16917855 2020-2021-A/Guangdong
# 24  BR2035      -1.18886368 2020-2021-A/Guangdong
# 25  BR1040       1.87069621 2020-2021-A/Guangdong
# 26  BR2013       0.08920727 2020-2021-A/Guangdong
# 27  BR2016      -1.39991055 2020-2021-A/Guangdong
# 28  BR1003      -1.09484865 2020-2021-A/Guangdong
# 29  BR1002      -1.55612906 2020-2021-A/Guangdong
# 30  BR1044       0.70631630 2020-2021-A/Guangdong
# ⋮   ⋮           ⋮           ⋮
# 433 BR2053       0.06727320 2021-2022-Flu B/Washington HA
# 434 BR1040      -0.82230459 2021-2022-Flu B/Washington HA
# 435 BR2036       1.56932867 2021-2022-Flu B/Washington HA
# 436 BR1047      -1.16838069 2021-2022-Flu B/Washington HA
# 437 BR2047       0.29704965 2021-2022-Flu B/Washington HA
# 438 BR2022      -0.57944847 2021-2022-Flu B/Washington HA
# 439 BR2019      -0.05549407 2021-2022-Flu B/Washington HA
# 440 BR2043      -0.80349606 2021-2022-Flu B/Washington HA
# 441 BR2024      -0.13791688 2021-2022-Flu B/Washington HA
# 442 BR2041      -1.29435230 2021-2022-Flu B/Washington HA
# 443 BR2039      -0.16392103 2021-2022-Flu B/Washington HA
# 444 BR2051       1.07279621 2021-2022-Flu B/Washington HA
# 445 BR2052       0.08857290 2021-2022-Flu B/Washington HA
# 446 BR1054      -0.24569813 2021-2022-Flu B/Washington HA
# 447 BR1026      -0.54731378 2021-2022-Flu B/Washington HA
# 448 BR2021       0.68493438 2021-2022-Flu B/Washington HA
# 449 BR2025       0.12305918 2021-2022-Flu B/Washington HA
# 450 BR2023      -0.73258874 2021-2022-Flu B/Washington HA
# 451 BR1028      -1.01685339 2021-2022-Flu B/Washington HA
# 452 BR2050      -0.68314870 2021-2022-Flu B/Washington HA
# 453 BR2046       1.31694607 2021-2022-Flu B/Washington HA
# 454 BR1058      -0.05811912 2021-2022-Flu B/Washington HA
# 455 BR2029       0.59370913 2021-2022-Flu B/Washington HA
# 456 BR1030      -0.46634236 2021-2022-Flu B/Washington HA
# 457 BR1059       0.17901648 2021-2022-Flu B/Washington HA
# 458 BR1050      -0.71006656 2021-2022-Flu B/Washington HA
# 459 BR2026       0.97350459 2021-2022-Flu B/Washington HA
# 460 BR1057      -0.58317063 2021-2022-Flu B/Washington HA
# 461 BR1041       0.76920519 2021-2022-Flu B/Washington HA
# 462 BR1056      -0.52186763 2021-2022-Flu B/Washington HA

# %%
df_wide <- pivot_wider(df[c("subjectGuid","residual","time_assay")], 
                       names_from = time_assay, values_from = residual)
mat <- as.matrix(df_wide[,-1])
rownames(mat) <- df_wide[[1]]

# %%
mat<-as.data.frame(mat)

# %%
mat$cohort<-substr(rownames(mat),1,3)

# %%
options(repr.plot.width = 12, repr.plot.height = 12)

ggpairs(as.data.frame(mat),                
        columns = 1:6,        
        aes(color = cohort, alpha = 0.5),
        upper = list(continuous = wrap("cor", method = "spearman", size = 4, color = "black")),
        lower = list(continuous = wrap("smooth", method = "lm", se = FALSE))) +
    scale_color_manual(values = c(BR2 = "#bf812d", BR1 = "#35978f")) +
    scale_fill_manual(values = c(BR2 = "#bf812d", BR1 = "#35978f")) +
    theme(strip.text = element_text(color = "black"),
          panel.grid = element_blank(),
          panel.background = element_rect(fill = "white"),
          axis.text = element_text(color = "black"))
# Out:
# plot without title
