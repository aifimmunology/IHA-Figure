# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import gc
import anndata
import h5py
from adjustText import adjust_text
import scanpy.external as sce
sc._settings.settings._vector_friendly=True
sc.settings.n_jobs = 60

# %%
adata=sc.read_h5ad("/home/jupyter/BRI_Figures_Final_V2/Figure6/03_TEAseq_PenSenior/TEA_scRNA.h5ad")

# %%
colors=pd.read_csv('/home/jupyter/BRI_Figures_Final_V2/Color_hex_codes/Cell_Type_Color_Annotation_and_Order.csv')
color_dict=dict(zip(colors.label, colors.color))

# %%
color_dict["CM CD4 T cell"]
# Out:
# '#6793A4'

# %%
adata.obs['cluster_dummy'] = adata.obs['AIFI_L3'] == 'CM CD4 T cell'
adata.obs['cluster_dummy'] = [str(item) for item in adata.obs['cluster_dummy']]
# Out:
# /opt/conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /opt/conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
with plt.rc_context({"figure.figsize": (3, 2),  "figure.frameon": False}):
    ax=sc.pl.umap(adata, color='cluster_dummy', show=False,
           palette={ "True": "#6793A4", "False": "lightgray"},
           frameon=False,size=0.1)      
    fig = ax.get_figure()
    fig.tight_layout()
    fig.savefig('FigureE.pdf', dpi=300, bbox_inches='tight')
# Out:
# /opt/conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1251: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /opt/conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
