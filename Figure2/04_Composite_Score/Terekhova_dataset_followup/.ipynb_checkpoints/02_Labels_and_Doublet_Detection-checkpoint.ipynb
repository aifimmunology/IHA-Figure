# %%
import scanpy as sc
import pandas as pd 
import numpy as np

# %%
import sys
import matplotlib.pyplot as plt
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
from multiprocessing import Pool

models.download_models()
# Out:
# 📂 Storing models in /root/.celltypist/data/models
# ⏩ Skipping [1/52]: Immune_All_Low.pkl (file exists)
# ⏩ Skipping [2/52]: Immune_All_High.pkl (file exists)
# ⏩ Skipping [3/52]: Adult_COVID19_PBMC.pkl (file exists)
# ⏩ Skipping [4/52]: Adult_CynomolgusMacaque_Hippocampus.pkl (file exists)
# ⏩ Skipping [5/52]: Adult_Human_MTG.pkl (file exists)
# ⏩ Skipping [6/52]: Adult_Human_PancreaticIslet.pkl (file exists)
# ⏩ Skipping [7/52]: Adult_Human_PrefrontalCortex.pkl (file exists)
# ⏩ Skipping [8/52]: Adult_Human_Skin.pkl (file exists)
# ⏩ Skipping [9/52]: Adult_Mouse_Gut.pkl (file exists)
# ⏩ Skipping [10/52]: Adult_Mouse_OlfactoryBulb.pkl (file exists)
# ⏩ Skipping [11/52]: Adult_Pig_Hippocampus.pkl (file exists)
# ⏩ Skipping [12/52]: Adult_RhesusMacaque_Hippocampus.pkl (file exists)
# ⏩ Skipping [13/52]: Autopsy_COVID19_Lung.pkl (file exists)
# ⏩ Skipping [14/52]: COVID19_HumanChallenge_Blood.pkl (file exists)
# ⏩ Skipping [15/52]: COVID19_Immune_Landscape.pkl (file exists)
# ⏩ Skipping [16/52]: Cells_Adult_Breast.pkl (file exists)
# ⏩ Skipping [17/52]: Cells_Fetal_Lung.pkl (file exists)
# ⏩ Skipping [18/52]: Cells_Human_Tonsil.pkl (file exists)
# ⏩ Skipping [19/52]: Cells_Intestinal_Tract.pkl (file exists)
# ⏩ Skipping [20/52]: Cells_Lung_Airway.pkl (file exists)
# ⏩ Skipping [21/52]: Developing_Human_Brain.pkl (file exists)
# ⏩ Skipping [22/52]: Developing_Human_Gonads.pkl (file exists)
# ⏩ Skipping [23/52]: Developing_Human_Hippocampus.pkl (file exists)
# ⏩ Skipping [24/52]: Developing_Human_Organs.pkl (file exists)
# ⏩ Skipping [25/52]: Developing_Human_Thymus.pkl (file exists)
# ⏩ Skipping [26/52]: Developing_Mouse_Brain.pkl (file exists)
# ⏩ Skipping [27/52]: Developing_Mouse_Hippocampus.pkl (file exists)
# ⏩ Skipping [28/52]: Fetal_Human_AdrenalGlands.pkl (file exists)
# ⏩ Skipping [29/52]: Fetal_Human_Pancreas.pkl (file exists)
# ⏩ Skipping [30/52]: Fetal_Human_Pituitary.pkl (file exists)
# ⏩ Skipping [31/52]: Fetal_Human_Retina.pkl (file exists)
# ⏩ Skipping [32/52]: Fetal_Human_Skin.pkl (file exists)
# ⏩ Skipping [33/52]: Healthy_Adult_Heart.pkl (file exists)
# ⏩ Skipping [34/52]: Healthy_COVID19_PBMC.pkl (file exists)
# ⏩ Skipping [35/52]: Healthy_Human_Liver.pkl (file exists)
# ⏩ Skipping [36/52]: Healthy_Mouse_Liver.pkl (file exists)
# ⏩ Skipping [37/52]: Human_AdultAged_Hippocampus.pkl (file exists)
# ⏩ Skipping [38/52]: Human_Colorectal_Cancer.pkl (file exists)
# ⏩ Skipping [39/52]: Human_Developmental_Retina.pkl (file exists)
# ⏩ Skipping [40/52]: Human_Embryonic_YolkSac.pkl (file exists)
# ⏩ Skipping [41/52]: Human_IPF_Lung.pkl (file exists)
# ⏩ Skipping [42/52]: Human_Longitudinal_Hippocampus.pkl (file exists)
# ⏩ Skipping [43/52]: Human_Lung_Atlas.pkl (file exists)
# ⏩ Skipping [44/52]: Human_PF_Lung.pkl (file exists)
# ⏩ Skipping [45/52]: Human_Placenta_Decidua.pkl (file exists)
# ⏩ Skipping [46/52]: Lethal_COVID19_Lung.pkl (file exists)
# ⏩ Skipping [47/52]: Mouse_Dentate_Gyrus.pkl (file exists)
# ⏩ Skipping [48/52]: Mouse_Isocortex_Hippocampus.pkl (file exists)
# ⏩ Skipping [49/52]: Mouse_Postnatal_DentateGyrus.pkl (file exists)
# ⏩ Skipping [50/52]: Mouse_Whole_Brain.pkl (file exists)
# ⏩ Skipping [51/52]: Nuclei_Lung_Airway.pkl (file exists)
# ⏩ Skipping [52/52]: Pan_Fetal_Human.pkl (file exists)

# %%
def process_and_annotate_pbmc(dataset):
    # Read data
    output_base_path="Labels_AIFI/"
    pbmc =dataset
    
    # Processing testing data
    sample_id = pbmc.obs['sample_id'].unique().tolist()[0]
    
    # Normalization and log transformation
    sc.pp.normalize_total(pbmc, target_sum=1e4)
    sc.pp.log1p(pbmc)
    
    # Annotations
    levels = ['L1', 'L2', 'L3', 'L3.5']
    models = {'L1': '/home/jupyter/BRI_Figures_Final_V1/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L1_2024-04-18.pkl',
              'L2': '/home/jupyter/BRI_Figures_Final_V1/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L2_2024-04-19.pkl',
              'L3': '/home/jupyter/BRI_Figures_Final_V1/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L3_2024-04-19.pkl'}
    predictions = {}

    for level, model_type in models.items():
        model_file = models[level]
        predictions[level] = celltypist.annotate(pbmc, model=model_file)

        # Write out labels
        predictions[level].predicted_labels.reset_index().to_csv(f'{output_base_path}/{sample_id}_{level}_predicted_labels.csv')
        # Write out probability matrix
        predictions[level].probability_matrix.reset_index().to_parquet(f'{output_base_path}/{sample_id}_{level}_probability_matrix.parquet')
        # Write out decision matrix
        predictions[level].decision_matrix.reset_index().to_parquet(f'{output_base_path}/{sample_id}_{level}_decision_matrix.parquet')

# %% [markdown]
# # adt

# %%
ADT_INFO=pd.read_csv("/home/jupyter/Maxim_dataset_followup/GEX_HTO_processed/raw_counts_h5ad/pbmc_hto_raw.csv")
ADT_INFO.index=ADT_INFO["Unnamed: 0"].tolist()
del ADT_INFO["Unnamed: 0"]
ADT_INFO.columns = [s.replace(".", "-") for s in ADT_INFO.columns]

# %% [markdown]
# # gex

# %%
adata=sc.read_h5ad("GEX_HTO_processed/raw_counts_h5ad/pbmc_gex_raw_with_var_obs.h5ad")

# %%
meta_data=pd.read_csv("/home/jupyter/Maxim_dataset_followup/GEX_HTO_processed/all_pbmcs/all_pbmcs_metadata.csv")
meta_data.index=meta_data["Unnamed: 0"].tolist()
del meta_data["Unnamed: 0"]
meta_data=meta_data.loc[adata.obs.index,:]
adata.obs=meta_data

# %%
adata.obs['sample_id'] = adata.obs['Donor_id'].astype(str) + '_' + adata.obs['Sex'].astype(str) + '_' + adata.obs['Age'].astype(str)+ '_' + adata.obs['Batch'].astype(str)

# %% [markdown]
# # AIFI Label Transfer

# %%
adata_list=[adata[adata.obs['sample_id']==donor].copy() for donor in adata.obs['sample_id'].unique()]

# %%
with Pool(processes=60) as pool:
    pool.map(process_and_annotate_pbmc, adata_list)
# Out:
# 🔬 Input data has 3405 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3405 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3581 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3581 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3405 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3224 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4897 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 3581 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3224 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 5947 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3284 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4897 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 4830 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 3224 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3284 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5947 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3396 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4897 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4025 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4830 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3396 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3284 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 3154 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 4025 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 5947 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8697 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3396 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 6420 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3154 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4830 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5100 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8697 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4025 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4917 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5100 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6420 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6814 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3154 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5248 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4917 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5097 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6814 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8697 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5135 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5100 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6420 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3775 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5248 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5097 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4599 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4917 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5135 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3775 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6814 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 4599 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5248 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5097 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 4438 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 4203 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3775 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 5135 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5346 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4894 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4599 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4203 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4438 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4671 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5346 cells and 36601 genes
# 🧬 1099 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 6288 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 4894 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4671 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 4930 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4438 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5898 cells and 36601 genes
# 🔗 Matching reference genes in the model

# %% [markdown]
# # Doublet Detection
