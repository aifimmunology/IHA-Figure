# %%
import scanpy as sc
import pandas as pd 
import numpy as np
import sys
import matplotlib.pyplot as plt
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
from multiprocessing import Pool
import os
models.download_models()

# %% [markdown]
# # adt

# %%
ADT_INFO=pd.read_csv("/home/jupyter/Maxim_dataset_followup/GEX_HTO_processed/raw_counts_h5ad/pbmc_hto_raw.csv")
ADT_INFO.index=ADT_INFO["Unnamed: 0"].tolist()
del ADT_INFO["Unnamed: 0"]
ADT_INFO.columns = [s.replace(".", "-") for s in ADT_INFO.columns]

# %% [markdown]
# # gex

# %%
adata=sc.read_h5ad("GEX_HTO_processed/raw_counts_h5ad/pbmc_gex_raw_with_var_obs.h5ad")

# %%
meta_data=pd.read_csv("/home/jupyter/Maxim_dataset_followup/GEX_HTO_processed/all_pbmcs/all_pbmcs_metadata.csv")
meta_data.index=meta_data["Unnamed: 0"].tolist()
del meta_data["Unnamed: 0"]
meta_data=meta_data.loc[adata.obs.index,:]
adata.obs=meta_data

# %%
adata.obs['sample_id'] = adata.obs['Donor_id'].astype(str) + '_' + adata.obs['Sex'].astype(str) + '_' + adata.obs['Age'].astype(str)+ '_' + adata.obs['Batch'].astype(str)

# %%
adata.obs['cell_barcode'] = adata.obs.index.tolist()

# %%
adata.write_h5ad("adata.h5ad")
# Out:
# ... storing 'orig.ident' as categorical
# ... storing 'Donor_id' as categorical
# ... storing 'Age_group' as categorical
# ... storing 'Sex' as categorical
# ... storing 'Tube_id' as categorical
# ... storing 'Batch' as categorical
# ... storing 'File_name' as categorical
# ... storing 'Cluster_names' as categorical
# ... storing 'sample_id' as categorical

# %% [markdown]
# # AIFI Label Transfer

# %%
def process_and_annotate_pbmc(dataset):
    # Read data
    output_base_path="Labels_AIFI/"
    pbmc =dataset
    
    # Processing testing data
    sample_id = pbmc.obs['sample_id'].unique().tolist()[0]
    
    # Normalization and log transformation
    sc.pp.normalize_total(pbmc, target_sum=1e4)
    sc.pp.log1p(pbmc)
    
    # Annotations
    levels = ['L1', 'L2', 'L3', 'L3.5']
    models = {'L1': '/home/jupyter/BRI_Figures_Final_V1/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L1_2024-04-18.pkl',
              'L2': '/home/jupyter/BRI_Figures_Final_V1/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L2_2024-04-19.pkl',
              'L3': '/home/jupyter/BRI_Figures_Final_V1/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L3_2024-04-19.pkl'}
    predictions = {}

    for level, model_type in models.items():
        model_file = models[level]
        predictions[level] = celltypist.annotate(pbmc, model=model_file)

        # Write out labels
        predictions[level].predicted_labels.reset_index().to_csv(f'{output_base_path}/{sample_id}_{level}_predicted_labels.csv')
        # Write out probability matrix
        predictions[level].probability_matrix.reset_index().to_parquet(f'{output_base_path}/{sample_id}_{level}_probability_matrix.parquet')
        # Write out decision matrix
        predictions[level].decision_matrix.reset_index().to_parquet(f'{output_base_path}/{sample_id}_{level}_decision_matrix.parquet')

# %%
adata_list=[adata[adata.obs['sample_id']==donor].copy() for donor in adata.obs['sample_id'].unique()]

# %%
with Pool(processes=60) as pool:
    pool.map(process_and_annotate_pbmc, adata_list)
# Out:
# 🔬 Input data has 3405 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3581 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3405 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3581 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3405 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3224 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4897 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3581 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3224 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5947 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3284 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4897 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4830 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3284 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3224 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5947 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# 🔬 Input data has 3396 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 4025 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4897 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4830 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 3154 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 3396 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3284 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4025 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5947 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 8697 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3154 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6420 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4830 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3396 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4917 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5100 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4025 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8697 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6420 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3154 cells and 36601 genes
# 🔬 Input data has 5248 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 5100 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 4917 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6814 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5097 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5135 cells and 36601 genes
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# 🔬 Input data has 5248 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6814 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3775 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6420 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 8697 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 5097 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5100 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4599 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5135 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4917 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3775 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4599 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4438 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5248 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6814 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 5097 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4894 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 5135 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4203 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3775 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4438 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 5346 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4599 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6288 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4203 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4894 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 4671 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 5898 cells and 36601 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 5346 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 4438 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3483 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6288 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4930 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4671 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 4203 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 4894 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5898 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3483 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4930 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5208 cells and 36601 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6742 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5346 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4525 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 6288 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 3957 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7398 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4671 cells and 36601 genes
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3483 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 5208 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5898 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4930 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6742 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 4525 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 7398 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6457 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3957 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 5962 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 4313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4845 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1946 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# 🔬 Input data has 5208 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6457 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4525 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5620 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6742 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3957 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7398 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 3926 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4845 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1946 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5962 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5620 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 4313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 3926 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6457 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 11448 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1003 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6055 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4845 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1946 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 466 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8732 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5962 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1003 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2950 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 466 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3926 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 11448 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 5620 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6055 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 8732 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 2471 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 2950 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5189 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1003 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 466 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6119 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2471 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 5189 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6055 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 11448 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 2950 cells and 36601 genes
# 🔬 Input data has 3239 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8732 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3202 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6119 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2471 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6209 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5189 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3202 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3239 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 6239 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 2677 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 6119 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6209 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4071 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 3239 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6087 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3202 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6239 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6595 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2677 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4071 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5527 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6087 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ✅ Prediction done!
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 6595 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6209 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2677 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6239 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10915 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5527 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4071 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2348 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6087 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# 🔬 Input data has 6595 cells and 36601 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 10915 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6122 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2348 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5527 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2818 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8449 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6122 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4078 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2818 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2348 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 10915 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8449 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 4078 cells and 36601 genes
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 6122 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5195 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 6313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2818 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4271 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 11079 cells and 36601 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5195 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 8449 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 4078 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4271 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 11079 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8371 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 11358 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 6313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5195 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8371 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4271 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 3683 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 3845 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 11079 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 11358 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3683 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5096 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 8371 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3845 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6079 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 2229 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3683 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5096 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9818 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 11358 cells and 36601 genes
# 🔬 Input data has 6079 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 2229 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3845 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4758 cells and 36601 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 9818 cells and 36601 genes
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2229 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5096 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6079 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4758 cells and 36601 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 10102 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6276 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 10613 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 9818 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5938 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 10102 cells and 36601 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 2981 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4758 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6276 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 10613 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 5080 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5938 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2981 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 10102 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 6276 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5080 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7069 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 3766 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 8725 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 2981 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5938 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 10613 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 7069 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3766 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 7479 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 8725 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5080 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# 🧬 2483 features used for prediction
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7802 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 7313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 7479 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 3766 cells and 36601 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 7069 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ...
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4150 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6315 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7441 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7553 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 5270 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7553 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6494 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7441 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 5270 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# 🔬 Input data has 4859 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6494 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 7553 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5313 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 4859 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5270 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 5163 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 6494 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5313 cells and 36601 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 5163 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 4859 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8798 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5262 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 7017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8798 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5163 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5262 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5508 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6569 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 5508 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 8798 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 5262 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6022 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6569 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7017 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 6022 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5508 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6251 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6569 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 6251 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 7483 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5832 cells and 36601 genes
# 🔬 Input data has 6022 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 5832 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 7483 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6251 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6757 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6521 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 7069 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6757 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 5832 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6521 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7483 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 8015 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 7069 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7096 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 6757 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 6521 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 8015 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6101 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 7096 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 7069 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 6101 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 8015 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5849 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 7096 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5237 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 14152 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 6101 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3877 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5849 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5237 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 14152 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 3877 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4903 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5849 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 5237 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 3877 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4903 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 14152 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 4903 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 5820 cells and 36601 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1099 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5820 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 1916 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 5820 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 2483 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!

# %% [markdown]
# # Doublet Detection

# %%
def doublet_detect(input_adata):
    adata = input_adata
    output_file = 'Doublet_Scores/' + adata.obs['sample_id'][0] + '.csv'
    if os.path.exists(output_file) and os.path.getsize(output_file) > 0:
        print(f"File {output_file} already exists and is not empty. Skipping processing.")
        return
    sc.external.pp.scrublet(adata)
    adata.obs[['cell_barcode', 'predicted_doublet', 'doublet_score']].to_csv(output_file)

# %%
with Pool(processes=60) as pool:
    pool.map(doublet_detect, adata_list)
# Out:
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 29.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 33.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 47.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 36.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 28.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 38.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 41.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 28.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 38.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 30.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 14.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 36.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.40
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 34.9%
# Estimated detectable doublet fraction = 31.2%
#
# Overall doublet rate:Overall doublet rate:
#
# 	Expected   = 5.0%	Expected   = 5.0%
#
# 	Estimated  = 0.1%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.7%
# Overall doublet rate:
# 	Expected   = 5.0%	Estimated  = 0.3%
#
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 39.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 35.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.48
#
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 14.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.4%Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 34.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 30.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 34.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 12.7%
# Overall doublet rate:
# Automatically set threshold at doublet score = 0.54
# 	Expected   = 5.0%Detected doublet rate = 0.0%
#
# Estimated detectable doublet fraction = 24.7%	Estimated  = 1.6%
#
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 35.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.0%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 22.6%
# Overall doublet rate:
# 	Expected   = 5.0%
#
# 	Estimated  = 0.8%Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 20.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.8%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 13.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 5.0%
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 37.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.6%
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 38.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 32.3%Automatically set threshold at doublet score = 0.49
#
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 23.7%
# Overall doublet rate:
# Overall doublet rate:	Expected   = 5.0%
#
# 	Expected   = 5.0%	Estimated  = 0.6%
#
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 15.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 43.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 22.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.9%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 15.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.9%
# Automatically set threshold at doublet score = 0.36
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 38.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.1%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 27.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 17.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.4%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 13.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.9%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 10.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 28.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.9%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 30.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 32.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 18.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.6%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
#
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 36.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 27.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 25.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 16.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 27.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 26.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.1%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 37.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 38.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 35.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 9.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 2.4%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 30.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 17.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 25.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 13.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 15.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
#
# Estimated detectable doublet fraction = 21.5%
# Overall doublet rate:Automatically set threshold at doublet score = 0.46
#
# Detected doublet rate = 0.1%
# 	Expected   = 5.0%Estimated detectable doublet fraction = 10.5%
#
# 	Estimated  = 0.2%Overall doublet rate:
#
# 	Expected   = 5.0%
# 	Estimated  = 1.0%Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 37.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 16.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 39.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.0%
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.0%
#
# Estimated detectable doublet fraction = 22.3%
# Overall doublet rate:	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 23.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 28.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# Automatically set threshold at doublet score = 0.54	Estimated  = 0.1%
#
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 16.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 29.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.48Automatically set threshold at doublet score = 0.46
#
# Detected doublet rate = 0.1%
# Detected doublet rate = 0.1%Estimated detectable doublet fraction = 22.5%
#
# Overall doublet rate:
# Estimated detectable doublet fraction = 31.4%	Expected   = 5.0%
#
# Overall doublet rate:
# 	Estimated  = 0.4%	Expected   = 5.0%
#
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 39.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 11.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.3%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 38.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 23.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 41.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 33.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 27.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 18.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 29.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 21.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 16.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 17.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 28.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 40.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 17.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 38.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 36.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 24.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 34.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 31.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 42.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 14.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 24.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 36.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 41.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 27.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 37.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 13.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 27.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 15.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 43.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 20.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 25.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 32.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 31.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
#
# Estimated detectable doublet fraction = 38.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%Automatically set threshold at doublet score = 0.50Automatically set threshold at doublet score = 0.55
#
# Detected doublet rate = 0.0%Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.7%
#
# Estimated detectable doublet fraction = 24.6%
# Overall doublet rate:
# Overall doublet rate:	Expected   = 5.0%
# 	Expected   = 5.0%
#
# 	Estimated  = 0.1%	Estimated  = 0.1%
#
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 15.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 20.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 41.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 17.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%Estimated detectable doublet fraction = 13.5%
#
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 30.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 17.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 9.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 16.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 44.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 28.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.9%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 15.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 9.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 18.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 31.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 43.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 29.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 17.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# Automatically set threshold at doublet score = 0.47	Estimated  = 0.4%
#
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 17.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 14.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 43.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 50.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 18.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 27.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 11.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 32.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 37.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 22.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 5.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.46
#
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 41.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 44.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 38.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 14.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 38.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 12.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 29.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 13.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 32.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 33.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.9%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 28.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 18.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 31.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 40.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
#
# Estimated detectable doublet fraction = 18.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
#
# Estimated detectable doublet fraction = 38.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 24.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.3%
#
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.6%Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 23.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 34.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 13.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 23.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 13.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
#
# Estimated detectable doublet fraction = 9.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 16.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Automatically set threshold at doublet score = 0.41Estimated detectable doublet fraction = 17.2%
# Detected doublet rate = 0.1%
# Overall doublet rate:
#
# Estimated detectable doublet fraction = 38.4%	Expected   = 5.0%
# Overall doublet rate:
#
# 	Expected   = 5.0%
# 	Estimated  = 0.7%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 21.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 14.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 11.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 13.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 42.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 23.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.8%Automatically set threshold at doublet score = 0.49
# Overall doublet rate:
# Detected doublet rate = 0.1%
#
# 	Expected   = 5.0%Estimated detectable doublet fraction = 30.2%
#
# 	Estimated  = 0.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 27.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 24.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 30.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 18.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 37.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.2%
#
# Estimated detectable doublet fraction = 17.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 1.0%Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 17.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 44.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 51.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 36.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 37.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 29.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 42.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 45.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.5%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 21.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 20.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.1%
# Automatically set threshold at doublet score = 0.51Estimated detectable doublet fraction = 34.6%
#
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 30.4%Overall doublet rate:
# Overall doublet rate:
#
# 	Expected   = 5.0%	Expected   = 5.0%
# 	Estimated  = 0.2%
# 	Estimated  = 0.1%
#
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 25.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 19.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 38.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 34.2%
# Overall doublet rate:
# Automatically set threshold at doublet score = 0.54	Expected   = 5.0%
# 	Estimated  = 0.3%
#
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 19.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 15.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 37.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 11.4%
# Overall doublet rate:
#
# 	Expected   = 5.0%
# 	Estimated  = 1.3%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 19.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 28.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 24.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 24.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 39.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 18.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 28.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 34.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 32.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 16.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 30.0%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.0%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 7.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 21.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 36.8%
# Overall doublet rate:
# 	Expected   = 5.0%
#
# 	Estimated  = 0.1%Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 21.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 26.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.8%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 31.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 26.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 13.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.6%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 36.8%
#
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 51.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 28.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 18.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 22.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.45
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 40.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 38.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 22.9%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 27.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 26.5%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 32.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 27.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 25.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 14.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.4%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 23.1%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 30.3%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 30.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 19.7%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 21.8%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.43
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 35.6%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.2%
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 49.4%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.1%
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 16.2%
# Overall doublet rate:
# 	Expected   = 5.0%
# 	Estimated  = 0.3%
