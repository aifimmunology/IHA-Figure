# %%
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(tidyr))
suppressPackageStartupMessages(library(tibble))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(stringr))
library(parallel)
library(reshape2)
source('/home//workspace/IHA_Figure_Revision/helper_function/helper_function_IHA.r')
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.3.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.3.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.3.3”
# Warning message:
# “package ‘reshape2’ was built under R version 4.3.3”
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
color_annotation<-read.csv('/home/workspace/IHA_Figure_Revision/Color_hex_codes/Cell_Type_Color_Annotation_and_Order.csv')
color_annotation$label<-gsub(" cell",'',color_annotation$label)
color_vector <- setNames(color_annotation$color, color_annotation$label)

# %%
meta_data=read.csv("Copy of Table S1 Cohort Details - Qiu.csv")

# %%
unique(meta_data$Group)
# Out:
# [1] "Control (HC1)"        "ACPA+ At-risk (ARI)"  "ACPA+ Early RA (ERA)"
# [4] "Control (HC2)"        ""

# %%
files <- list.files("sample_normalized_count_average/", full.names = FALSE)
file_names <- tools::file_path_sans_ext(files)

# %%
colnames(meta_data)
# Out:
#  [1] "Group"
#  [2] "Subject.ID"
#  [3] "Converter.Status"
#  [4] "Sample.ID"
#  [5] "Age.at.sample.collection..yrs."
#  [6] "Age.at.diagnosis.of.clinical.RA..yrs."
#  [7] "BMI"
#  [8] "BMI.at.diagnosis.of.clinical.RA"
#  [9] "Sex"
# [10] "Anti.CCP3..units."
# [11] "Rheumatoid.factor..RF..IgA..U.mL."
# [12] "Rheumatoid.factor..RF..IgM..U.mL."
# [13] "Time.to.clinical.RA.diagnosis..days."
# [14] "Time.from.initial.visit.to.sample.collection..days."
# [15] "Alanine.transaminase..ALT..U.L."
# [16] "Albumin..g.dL."
# [17] "Alkaline.phosphatase..IU.L."
# [18] "Anion.gap..mEq.L."
# [19] "High.sensitivity.C.reactive.protein..hs.CRP..mg.L."
# [20] "High.density.lipoprotein..HDL..mg.dL."
# [21] "Low.density.lipoprotein..LDL..mg.dL."
# [22] "Total.cholesterol..mg.dL."
# [23] "Platelet.count..10.3.uL."
# [24] "Total.protein..g.dL."
# [25] "Red.blood.cell..RBC..count..10.6.uL."
# [26] "Erythrocyte.sedimentation.rate...Westergren.method..ESR..mm.h."
# [27] "Shared.epitope"
# [28] "Sodium..mmol.L."
# [29] "Triglycerides..mg.dL."
# [30] "White.blood.cell..WBC..count..10.3.uL."
# [31] "Used.in.Longtinudinal.analysis"
# [32] "Used.in.cross.sectional.analysis"
# [33] "Used.in.TEA.seq.experiment"
# [34] "Used.in.B.cells.activation.experiment"
# [35] "Used.in.T.cell.phenotyping.experiment"
# [36] "Used.in.VDJ.experiment"

# %%
meta_data<-meta_data %>% filter(Sample.ID %in% file_names,Group %in% c("Control (HC1)",
                                                                       'ACPA+ At-risk (ARI)',
                                                                       'ACPA+ Early RA (ERA)'))

# %%
meta_data$pbmc_sample_id<-meta_data$Sample.ID

# %%
file_list<-paste0("sample_normalized_count_average/", meta_data$pbmc_sample_id, ".csv")

# %%
df_list<-read_pseudobulk_expression(file_list,
                                    mc_cores = 15)
# Out:
# [1] "Total reading time: 22.5420000000013 seconds"
# [1] "The length of the list matches the length of the input path."

# %%
deseq2_result_Y1D0<-read.csv('/home//workspace/IHA_Figure_Revision/Figure1/02_DEG/Deseq2_Result_Y1D0.csv')

# %%
 #filter significant genes 
deseq2_result_Y1D0_AgeGroup_sig<-deseq2_result_Y1D0 %>% 
  filter(contrast == "cohort.cohortGuid") %>%
  filter(padj < 0.05, 
         abs(log2FoldChange) > 0.1)

# %%
df_degs_counts<-as.data.frame(table(deseq2_result_Y1D0_AgeGroup_sig$celltype,
                                    deseq2_result_Y1D0_AgeGroup_sig$Direction))

# %%
df_degs_counts_filtered<-df_degs_counts %>% filter(Var2=="HigherInBR2") %>% arrange(Var1)   %>% filter(Freq>20)

# %%
score_df_list <- mclapply(unique(df_degs_counts_filtered$Var1), function(celltype_single) {
    top_n <- 100
    Direction_of_DEG <- "HigherInBR2"
    
    selected_genes <- deseq2_result_Y1D0_AgeGroup_sig %>%
        filter(celltype == celltype_single, Direction == Direction_of_DEG) %>%
        arrange(padj, desc(abs(log2FoldChange))) %>% 
        slice_head(n = top_n) %>%
        select(gene) %>%
        pull()
    selected_genes<-intersect(selected_genes,rownames(df_list[[1]]))
    print(length(selected_genes))
    long_format <- filter_genes_and_celltype(df_list, selected_genes, celltype_single, longformat = TRUE) %>%
        left_join(meta_data) %>%
        filter(!is.na(Mean_Expression)) %>%
        group_by(Gene) %>%
        mutate(Z_score_Mean_Expression = scale(Mean_Expression)) %>%
        ungroup()
    
    composite_score_df <- long_format %>%
        group_by(pbmc_sample_id) %>%
        summarise(
            composite_score_sum_mean = sum(Mean_Expression, na.rm = TRUE),
            composite_score_sum_scaled_mean = sum(Z_score_Mean_Expression, na.rm = TRUE)
        ) %>%
        left_join(meta_data) %>%
        mutate(celltype = celltype_single) %>%
        as.data.frame()
    
    return(composite_score_df)
}, mc.cores = 10)

# %%
composite_score_df_all<-do.call(rbind,score_df_list)

# %%
write.csv(composite_score_df_all,'RA_CompositeScore_Up.csv')

# %%
library(ggpubr)

# %%
options(repr.plot.width = 250/25.4, repr.plot.height = 220/25.4)

# %%
composite_score_df_all$Group_new<-paste0(composite_score_df_all$Group," ",composite_score_df_all$Converter.Status)

# %%
composite_score_df_all$Group_new<- factor(composite_score_df_all$Group_new,levels=c('Control (HC1) NA',
                                                                                    'ACPA+ At-risk (ARI) NONC',
                                                                                    'ACPA+ At-risk (ARI) CONV',
                                                                                    'ACPA+ Early RA (ERA) NA'
                                                                                    ))
# Out:
# [1] "ACPA+ At-risk (ARI) CONV" "ACPA+ Early RA (ERA) NA"
# [3] "ACPA+ At-risk (ARI) NONC" "Control (HC1) NA"

# %%
group_levels <- levels(factor(composite_score_df_all$Group_new))
my_comparisons <- combn(group_levels, 2, simplify = FALSE)
options(repr.plot.width = 8, repr.plot.height = 8)

p <- ggboxplot(composite_score_df_all %>% filter(celltype=="CM CD8 T cell"), x = "Group_new", y = "Age.at.sample.collection..yrs.",
               color = "Group_new", palette = "jco", add = "jitter") +
     stat_compare_means(method = "wilcox.test", comparisons = my_comparisons, 
                        group.by = "celltype") + 
theme(axis.text.x = element_text(angle = 90, 
                                                                                  vjust = 0.5, hjust=1))+ylab("Age")

p
# Out:
# Warning message in wilcox.test.default(c(51, 37, 59, 36, 57, 78, 70, 46, 45, 34, :
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(c(51, 37, 59, 36, 57, 78, 70, 46, 45, 34, :
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(c(78, 40, 39, 61, 74, 55, 66, 76, 71, 74, :
# “cannot compute exact p-value with ties”
# plot without title

# %%
options(repr.plot.width = 250/25.4, repr.plot.height = 280/25.4)

composite_score_df_all$Group_new<- factor(composite_score_df_all$Group_new,levels=c('Control (HC1) NA',
                                                                                    'ACPA+ At-risk (ARI) NONC',
                                                                                    'ACPA+ At-risk (ARI) CONV',
                                                                                    'ACPA+ Early RA (ERA) NA'
                                                                                    ))
group_levels <- levels(factor(composite_score_df_all$Group_new))
my_comparisons <- combn(group_levels, 2, simplify = FALSE)

p <- ggboxplot(composite_score_df_all, 
               x = "Group_new", 
               y = "composite_score_sum_scaled_mean",
               color = "Group_new", palette = "jco", add = "jitter") +
     stat_compare_means(method = "wilcox.test", 
                        comparisons = my_comparisons, 
                        group.by = "celltype") +
     facet_wrap(~celltype,
                ncol=4,
                scale="free_y")+ 
theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1))

p
# Out:
# plot without title

# %%
options(repr.plot.width = 300/25.4, repr.plot.height = 200/25.4)
spearman_df <- composite_score_df_all %>%
  filter(Group %in% c('ACPA+ At-risk (ARI)', 
                      'ACPA+ Early RA (ERA)', 
                      'Control (HC1)')) %>%
  group_by(celltype, Group_new) %>%
  summarize(
    rho = cor(Age.at.sample.collection..yrs., composite_score_sum_scaled_mean, method = "spearman"),
    .groups = "drop"
  )
ggplot(composite_score_df_all %>% filter(Group %in% c('ACPA+ At-risk (ARI)','ACPA+ Early RA (ERA)',"Control (HC1)")), 
                                         aes(x=Age.at.sample.collection..yrs., y=composite_score_sum_scaled_mean, color=Group_new, shape=Group_new)) +
  geom_point() + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)+
     facet_wrap(~celltype,ncol=4,scale="free")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
spearman_df %>% arrange(celltype,rho)
# Out:
#    celltype                  Group_new                rho
# 1  CM CD4 T cell             ACPA+ At-risk (ARI) CONV 0.07819622
# 2  CM CD4 T cell             ACPA+ At-risk (ARI) NONC 0.24818288
# 3  CM CD4 T cell             ACPA+ Early RA (ERA) NA  0.42009570
# 4  CM CD4 T cell             Control (HC1) NA         0.72329283
# 5  CM CD8 T cell             ACPA+ At-risk (ARI) CONV 0.20524942
# 6  CM CD8 T cell             ACPA+ Early RA (ERA) NA  0.33790307
# 7  CM CD8 T cell             ACPA+ At-risk (ARI) NONC 0.33885343
# 8  CM CD8 T cell             Control (HC1) NA         0.66962591
# 9  Core naive CD4 T cell     ACPA+ Early RA (ERA) NA  0.25114417
# 10 Core naive CD4 T cell     ACPA+ At-risk (ARI) NONC 0.39418468
# 11 Core naive CD4 T cell     ACPA+ At-risk (ARI) CONV 0.58791357
# 12 Core naive CD4 T cell     Control (HC1) NA         0.64279245
# 13 Core naive CD8 T cell     ACPA+ At-risk (ARI) CONV 0.33890603
# 14 Core naive CD8 T cell     ACPA+ Early RA (ERA) NA  0.37443313
# 15 Core naive CD8 T cell     ACPA+ At-risk (ARI) NONC 0.38812652
# 16 Core naive CD8 T cell     Control (HC1) NA         0.65348549
# 17 GZMB- CD27+ EM CD4 T cell ACPA+ At-risk (ARI) CONV 0.17340253
# 18 GZMB- CD27+ EM CD4 T cell ACPA+ Early RA (ERA) NA  0.33790307
# 19 GZMB- CD27+ EM CD4 T cell ACPA+ At-risk (ARI) NONC 0.34794068
# 20 GZMB- CD27+ EM CD4 T cell Control (HC1) NA         0.47432676
# 21 GZMB- CD27- EM CD4 T cell ACPA+ Early RA (ERA) NA  0.23744540
# 22 GZMB- CD27- EM CD4 T cell ACPA+ At-risk (ARI) CONV 0.28405165
# 23 GZMB- CD27- EM CD4 T cell Control (HC1) NA         0.40129133
# 24 GZMB- CD27- EM CD4 T cell ACPA+ At-risk (ARI) NONC 0.49192310
# 25 GZMK+ CD27+ EM CD8 T cell ACPA+ At-risk (ARI) CONV 0.20602260
# 26 GZMK+ CD27+ EM CD8 T cell ACPA+ At-risk (ARI) NONC 0.22596960
# 27 GZMK+ CD27+ EM CD8 T cell ACPA+ Early RA (ERA) NA  0.22831288
# 28 GZMK+ CD27+ EM CD8 T cell Control (HC1) NA         0.45879160
# 29 Naive CD4 Treg            ACPA+ At-risk (ARI) NONC 0.33279526
# 30 Naive CD4 Treg            ACPA+ At-risk (ARI) CONV 0.36653174
# 31 Naive CD4 Treg            ACPA+ Early RA (ERA) NA  0.56164969
# 32 Naive CD4 Treg            Control (HC1) NA         0.72470511

# %% [markdown]
# # first TP VS LASTEST TP
