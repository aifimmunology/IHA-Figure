# %%
import scanpy as sc
import pandas as pd 
import numpy as np
import sys
import matplotlib.pyplot as plt
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
from multiprocessing import Pool
import os
# Out:
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/workspace/Aux_Envir/Python_BRI_Figures/lib/python3.11/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %%
adata=sc.read_h5ad("dataset/08984b3c-3189-4732-be22-62f1fe8f15a4.h5ad")

# %%
adata.var_names=adata.var['feature_name'].tolist()

# %%
adata.obs['cell_barcode'] = adata.obs.index.tolist()

# %%
adata_list=[adata[adata.obs['donor_id']==donor].copy() for donor in adata.obs['donor_id'].unique()]

# %% [markdown]
# # AIFI Label Transfer

# %%
def process_and_annotate_pbmc(dataset):
    # Read data
    output_base_path="Labels_AIFI/"
    pbmc =dataset
    
    # Processing testing data
    sample_id = pbmc.obs['donor_id'].unique().tolist()[0]
    
    # Normalization and log transformation
    sc.pp.normalize_total(pbmc, target_sum=1e4)
    sc.pp.log1p(pbmc)
    
    # Annotations
    levels = ['L1', 'L2', 'L3', 'L3.5']
    models = {'L1': '/home//workspace/private/bri_figure_all_files_test/jupyter/BRI_Figures_Final_V2/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L1_2024-04-18.pkl',
              'L2': '/home//workspace/private/bri_figure_all_files_test/jupyter/BRI_Figures_Final_V2/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L2_2024-04-19.pkl',
              'L3': '/home//workspace/private/bri_figure_all_files_test/jupyter/BRI_Figures_Final_V2/Dataset/Celltypist_Models/ref_pbmc_clean_celltypist_model_AIFI_L3_2024-04-19.pkl'}
    predictions = {}

    for level, model_type in models.items():
        model_file = models[level]
        predictions[level] = celltypist.annotate(pbmc, model=model_file)

        # Write out labels
        predictions[level].predicted_labels.reset_index().to_csv(f'{output_base_path}/{sample_id}_{level}_predicted_labels.csv')
        # Write out probability matrix
        predictions[level].probability_matrix.reset_index().to_parquet(f'{output_base_path}/{sample_id}_{level}_probability_matrix.parquet')
        # Write out decision matrix
        predictions[level].decision_matrix.reset_index().to_parquet(f'{output_base_path}/{sample_id}_{level}_decision_matrix.parquet')

# %%
with Pool(processes=60) as pool:
    pool.map(process_and_annotate_pbmc, adata_list)
# Out:
# 🔬 Input data has 1501 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1278 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1297 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 2216 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1776 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1317 cells and 36469 genes
# ✅ Prediction done!
# 🔬 Input data has 1501 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1278 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# 🔬 Input data has 1281 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1297 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1169 cells and 36469 genes
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1374 cells and 36469 genes
# 🔬 Input data has 2216 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1776 cells and 36469 genes
# 🔬 Input data has 1288 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1317 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1834 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1281 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1359 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1501 cells and 36469 genes
# 🔬 Input data has 1278 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1169 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1563 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1297 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1374 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1103 cells and 36469 genes
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1288 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 2216 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1431 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1834 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 1279 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1776 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1359 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1317 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1324 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1563 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1103 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1281 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1324 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1169 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1767 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1093 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1289 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1431 cells and 36469 genes
# 🔬 Input data has 1374 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1221 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# 🔬 Input data has 1170 cells and 36469 genes
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1279 cells and 36469 genes
# 🔬 Input data has 1288 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1058 cells and 36469 genes
# 🧬 1846 features used for prediction
# 🧬 1065 features used for prediction
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1834 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1324 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 1252 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1359 cells and 36469 genes
# ✅ Prediction done!
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1324 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1767 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1378 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 980 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1103 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1093 cells and 36469 genes
# 🧬 1065 features used for prediction
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1563 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔬 Input data has 1289 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1478 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1221 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1194 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1170 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1431 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1493 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1449 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 1262 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1058 cells and 36469 genes
# 🔬 Input data has 1252 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1331 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1279 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1566 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1378 cells and 36469 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1306 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🧬 1846 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 980 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1324 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1633 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1893 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1478 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1324 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1194 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 1767 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1462 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1255 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1449 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1493 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1262 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1289 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1093 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 1287 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1331 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1455 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1221 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1170 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1566 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1151 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1058 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1633 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1306 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1252 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1558 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1243 cells and 36469 genes
# 🔬 Input data has 2425 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# 🔬 Input data has 1332 cells and 36469 genes
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1378 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1893 cells and 36469 genes
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 2073 cells and 36469 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1462 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1255 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 980 cells and 36469 genes
# 🔬 Input data has 1478 cells and 36469 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1194 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1764 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 2684 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1287 cells and 36469 genes
# 🔬 Input data has 1455 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 1262 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1236 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# 🔬 Input data has 1701 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1449 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1493 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1151 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1331 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1719 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1463 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1243 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1552 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 2425 cells and 36469 genes
# 🔬 Input data has 1566 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1558 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1369 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1501 cells and 36469 genes
# 🔬 Input data has 1332 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# 🔬 Input data has 1435 cells and 36469 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2073 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1950 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1306 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1633 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1764 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1593 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1893 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 2684 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1255 cells and 36469 genes
# 🔬 Input data has 1185 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1468 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 1559 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# 🔬 Input data has 1338 cells and 36469 genes
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# 🔬 Input data has 1433 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1236 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1701 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1182 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1455 cells and 36469 genes
# 🧬 1065 features used for prediction
# 🔬 Input data has 1287 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1462 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1552 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1499 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1329 cells and 36469 genes
# ✅ Prediction done!
# 🔬 Input data has 853 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1463 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1297 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# 🔬 Input data has 1449 cells and 36469 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 1501 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1151 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1719 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1435 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1091 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1369 cells and 36469 genes
# 🔬 Input data has 2425 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1168 cells and 36469 genes
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1950 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# 🔬 Input data has 976 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1243 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1289 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1130 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2073 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1332 cells and 36469 genes
# 🔬 Input data has 1558 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🧬 1065 features used for prediction
# 🔬 Input data has 1229 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# 🔬 Input data has 1652 cells and 36469 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1593 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1559 cells and 36469 genes
# 🔬 Input data has 1185 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1217 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1468 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1332 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1433 cells and 36469 genes
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 1764 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2684 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1066 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1460 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1182 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1376 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1499 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1338 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1701 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1236 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# 🔬 Input data has 1329 cells and 36469 genes
# 🔬 Input data has 1186 cells and 36469 genes
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 853 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1955 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1409 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1297 cells and 36469 genes
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1449 cells and 36469 genes
# 🔬 Input data has 1091 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1552 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1158 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 904 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# 🔬 Input data has 1423 cells and 36469 genes
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1596 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1501 cells and 36469 genes
# 🔬 Input data has 1463 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 976 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1130 cells and 36469 genes
# 🔬 Input data has 1168 cells and 36469 genes
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 1177 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1289 cells and 36469 genes
# 🧬 1065 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1719 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 1435 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1229 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1369 cells and 36469 genes
# 🧬 1065 features used for prediction
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 936 cells and 36469 genes
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1950 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1041 cells and 36469 genes
# 🔬 Input data has 1652 cells and 36469 genes
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1217 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1332 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1201 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1779 cells and 36469 genes
# 🧬 1846 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 1460 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1066 cells and 36469 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🔬 Input data has 974 cells and 36469 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1135 cells and 36469 genes
# 🔬 Input data has 1448 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1464 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1185 cells and 36469 genes
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1433 cells and 36469 genes
# 🔬 Input data has 1593 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 912 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1468 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 866 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1955 cells and 36469 genes
# 🧬 1846 features used for prediction
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ✅ Prediction done!
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1559 cells and 36469 genes
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 1376 cells and 36469 genes
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🔬 Input data has 1186 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🔬 Input data has 1182 cells and 36469 genes
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# 🔬 Input data has 818 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 2731 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# 🔬 Input data has 1409 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1719 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1338 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 904 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 853 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1158 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1660 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1499 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1423 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🔬 Input data has 1329 cells and 36469 genes
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1610 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 932 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1297 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 707 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1455 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1495 cells and 36469 genes
# ...
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1588 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 815 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1697 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1231 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 711 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1557 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1721 cells and 36469 genes
# 🔬 Input data has 1614 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1203 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1439 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1360 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 842 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1164 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1588 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 815 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 876 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1065 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 1231 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1697 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 933 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1401 cells and 36469 genes
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1721 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 876 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1439 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1277 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1105 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1070 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🔬 Input data has 1164 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 842 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 1431 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 815 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1360 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1588 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 933 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🔬 Input data has 1401 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🔬 Input data has 1105 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1431 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🔬 Input data has 974 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🔬 Input data has 1277 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1408 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1070 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# 🔬 Input data has 876 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🖋️ Predicting labels
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 922 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1288 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1140 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 894 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 933 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🔬 Input data has 1314 cells and 36469 genes
# ✅ Prediction done!
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 871 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1786 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1401 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 974 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1408 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 922 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1105 cells and 36469 genes
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# 🔬 Input data has 1277 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1431 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 1070 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1288 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1944 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1140 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 894 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 871 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1314 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1786 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 974 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1374 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🔬 Input data has 922 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1408 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1161 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# 🧬 1846 features used for prediction
# ✅ Prediction done!
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1288 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🔬 Input data has 1944 cells and 36469 genes
# 🖋️ Predicting labels
# 🔗 Matching reference genes in the model
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1140 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🔬 Input data has 871 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 894 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 883 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1314 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1786 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1161 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1374 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ✅ Prediction done!
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 1065 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1944 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 883 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🧬 1846 features used for prediction
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🧬 2395 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ✅ Prediction done!
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 1374 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🔬 Input data has 1161 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 1846 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 883 cells and 36469 genes
# 🔗 Matching reference genes in the model
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🧬 2395 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!

# %% [markdown]
# # Doublet Detection

# %%
def doublet_detect(input_adata):
    adata = input_adata
    output_file = 'Doublet_Score/' + adata.obs['donor_id'][0] + '.csv'
    if os.path.exists(output_file) and os.path.getsize(output_file) > 0:
        print(f"File {output_file} already exists and is not empty. Skipping processing.")
        return
    sc.external.pp.scrublet(adata)
    adata.obs[['cell_barcode', 'predicted_doublet', 'doublet_score']].to_csv(output_file)

# %%
with Pool(processes=10) as pool:
    pool.map(doublet_detect, adata_list)

# %%
doublet_detect
